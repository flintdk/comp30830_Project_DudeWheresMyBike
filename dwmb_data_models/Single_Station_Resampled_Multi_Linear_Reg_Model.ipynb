# %%
# Library Imports.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Allows plots to appear directly in the notebook.
# %matplotlib inline

from patsy import dmatrices
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.model_selection import cross_validate
from sklearn.model_selection import cross_val_score 

import pickle

# %%
# Read CSV files into Data Frames:
weather = pd.read_csv('working_weatherHistoryResampled_asof_2022.04.06.csv', keep_default_na=True, delimiter=',', skipinitialspace=True)
station = pd.read_csv('working_stationStateResampled_asof_2022.04.06.csv', keep_default_na=True, delimiter=',', skipinitialspace=True)

# %%
weather.shape
# Out:
# (684, 7)

# %%
station.shape
# Out:
# (75240, 6)

# %%
weather.head()
# Out:
#            weatherHour  latitude  longitude       description    temp  \
# 0  2022-02-22 12:00:00     53.35      -6.26        few clouds  282.81
# 1  2022-02-24 10:00:00     53.35      -6.26  scattered clouds  276.31
# 2  2022-03-01 09:00:00     53.35      -6.26         clear sky  277.21
# 3  2022-03-01 10:00:00     53.35      -6.26  scattered clouds  279.13
# 4  2022-03-01 11:00:00     53.35      -6.26     broken clouds  280.61
#
#    humidity  wind_speed
# 0        71       10.80
# 1        80        9.77
# 2        86        0.98
# 3        83        1.78
# 4        80        3.65

# %%
station.head()
# Out:
#        ID  stationId          weatherHour status  available_bike_stands  \
# 0  143661          1  2022-02-22 12:00:00   OPEN                     12
# 1  143662          2  2022-02-22 12:00:00   OPEN                     18
# 2  143663          3  2022-02-22 12:00:00   OPEN                     20
# 3  143664          4  2022-02-22 12:00:00   OPEN                     22
# 4  143665          5  2022-02-22 12:00:00   OPEN                     38
#
#    available_bikes
# 0               18
# 1                2
# 2               13
# 3               13
# 4                2

# %%
stationWeather = pd.merge(station, weather, how="left", on=["weatherHour"])

# %%
stationWeather.head()
# Out:
#        ID  stationId          weatherHour status  available_bike_stands  \
# 0  143661          1  2022-02-22 12:00:00   OPEN                     12
# 1  143662          2  2022-02-22 12:00:00   OPEN                     18
# 2  143663          3  2022-02-22 12:00:00   OPEN                     20
# 3  143664          4  2022-02-22 12:00:00   OPEN                     22
# 4  143665          5  2022-02-22 12:00:00   OPEN                     38
#
#    available_bikes  latitude  longitude description    temp  humidity  \
# 0               18     53.35      -6.26  few clouds  282.81        71
# 1                2     53.35      -6.26  few clouds  282.81        71
# 2               13     53.35      -6.26  few clouds  282.81        71
# 3               13     53.35      -6.26  few clouds  282.81        71
# 4                2     53.35      -6.26  few clouds  282.81        71
#
#    wind_speed
# 0        10.8
# 1        10.8
# 2        10.8
# 3        10.8
# 4        10.8

# %%
stationWeather.tail()
# Out:
#            ID  stationId          weatherHour status  available_bike_stands  \
# 75235  218896        106  2022-04-04 10:00:00   OPEN                      3
# 75236  218897        107  2022-04-04 10:00:00   OPEN                     29
# 75237  218898        108  2022-04-04 10:00:00   OPEN                     37
# 75238  218899        109  2022-04-04 10:00:00   OPEN                      4
# 75239  218900        110  2022-04-04 10:00:00   OPEN                     28
#
#        available_bikes  latitude  longitude    description    temp  humidity  \
# 75235               17     53.35      -6.26  broken clouds  285.57        86
# 75236               11     53.35      -6.26  broken clouds  285.57        86
# 75237                3     53.35      -6.26  broken clouds  285.57        86
# 75238               24     53.35      -6.26  broken clouds  285.57        86
# 75239                2     53.35      -6.26  broken clouds  285.57        86
#
#        wind_speed
# 75235       10.84
# 75236       10.84
# 75237       10.84
# 75238       10.84
# 75239       10.84

# %%
stationWeather.dtypes
# Out:
# ID                         int64
# stationId                  int64
# weatherHour               object
# status                    object
# available_bike_stands      int64
# available_bikes            int64
# latitude                 float64
# longitude                float64
# description               object
# temp                     float64
# humidity                   int64
# wind_speed               float64
# dtype: object

# %%
stationWeather[['weatherDate', 'weatherHour']] = stationWeather['weatherHour'].str.split(' ', expand=True)
stationWeather
# Out:
#            ID  stationId weatherHour status  available_bike_stands  \
# 0      143661          1    12:00:00   OPEN                     12
# 1      143662          2    12:00:00   OPEN                     18
# 2      143663          3    12:00:00   OPEN                     20
# 3      143664          4    12:00:00   OPEN                     22
# 4      143665          5    12:00:00   OPEN                     38
# ...       ...        ...         ...    ...                    ...
# 75235  218896        106    10:00:00   OPEN                      3
# 75236  218897        107    10:00:00   OPEN                     29
# 75237  218898        108    10:00:00   OPEN                     37
# 75238  218899        109    10:00:00   OPEN                      4
# 75239  218900        110    10:00:00   OPEN                     28
#
#        available_bikes  latitude  longitude    description    temp  humidity  \
# 0                   18     53.35      -6.26     few clouds  282.81        71
# 1                    2     53.35      -6.26     few clouds  282.81        71
# 2                   13     53.35      -6.26     few clouds  282.81        71
# 3                   13     53.35      -6.26     few clouds  282.81        71
# 4                    2     53.35      -6.26     few clouds  282.81        71
# ...                ...       ...        ...            ...     ...       ...
# 75235               17     53.35      -6.26  broken clouds  285.57        86
# 75236               11     53.35      -6.26  broken clouds  285.57        86
# 75237                3     53.35      -6.26  broken clouds  285.57        86
# 75238               24     53.35      -6.26  broken clouds  285.57        86
# 75239                2     53.35      -6.26  broken clouds  285.57        86
#
#        wind_speed weatherDate
# 0           10.80  2022-02-22
# 1           10.80  2022-02-22
# 2           10.80  2022-02-22
# 3           10.80  2022-02-22
# 4           10.80  2022-02-22
# ...           ...         ...
# 75235       10.84  2022-04-04
# 75236       10.84  2022-04-04
# 75237       10.84  2022-04-04
# 75238       10.84  2022-04-04
# 75239       10.84  2022-04-04
#
# [75240 rows x 13 columns]

# %%
stationWeather[['weatherHour', 'weatherMinute', 'weatherSecond']] = stationWeather['weatherHour'].str.split(':', expand=True)
stationWeather
# Out:
#            ID  stationId weatherHour status  available_bike_stands  \
# 0      143661          1          12   OPEN                     12
# 1      143662          2          12   OPEN                     18
# 2      143663          3          12   OPEN                     20
# 3      143664          4          12   OPEN                     22
# 4      143665          5          12   OPEN                     38
# ...       ...        ...         ...    ...                    ...
# 75235  218896        106          10   OPEN                      3
# 75236  218897        107          10   OPEN                     29
# 75237  218898        108          10   OPEN                     37
# 75238  218899        109          10   OPEN                      4
# 75239  218900        110          10   OPEN                     28
#
#        available_bikes  latitude  longitude    description    temp  humidity  \
# 0                   18     53.35      -6.26     few clouds  282.81        71
# 1                    2     53.35      -6.26     few clouds  282.81        71
# 2                   13     53.35      -6.26     few clouds  282.81        71
# 3                   13     53.35      -6.26     few clouds  282.81        71
# 4                    2     53.35      -6.26     few clouds  282.81        71
# ...                ...       ...        ...            ...     ...       ...
# 75235               17     53.35      -6.26  broken clouds  285.57        86
# 75236               11     53.35      -6.26  broken clouds  285.57        86
# 75237                3     53.35      -6.26  broken clouds  285.57        86
# 75238               24     53.35      -6.26  broken clouds  285.57        86
# 75239                2     53.35      -6.26  broken clouds  285.57        86
#
#        wind_speed weatherDate weatherMinute weatherSecond
# 0           10.80  2022-02-22            00            00
# 1           10.80  2022-02-22            00            00
# 2           10.80  2022-02-22            00            00
# 3           10.80  2022-02-22            00            00
# 4           10.80  2022-02-22            00            00
# ...           ...         ...           ...           ...
# 75235       10.84  2022-04-04            00            00
# 75236       10.84  2022-04-04            00            00
# 75237       10.84  2022-04-04            00            00
# 75238       10.84  2022-04-04            00            00
# 75239       10.84  2022-04-04            00            00
#
# [75240 rows x 15 columns]

# %%
stationWeather['cal_bike_stands'] = stationWeather.available_bike_stands + stationWeather.available_bikes
stationWeather
# Out:
#            ID  stationId weatherHour status  available_bike_stands  \
# 0      143661          1          12   OPEN                     12
# 1      143662          2          12   OPEN                     18
# 2      143663          3          12   OPEN                     20
# 3      143664          4          12   OPEN                     22
# 4      143665          5          12   OPEN                     38
# ...       ...        ...         ...    ...                    ...
# 75235  218896        106          10   OPEN                      3
# 75236  218897        107          10   OPEN                     29
# 75237  218898        108          10   OPEN                     37
# 75238  218899        109          10   OPEN                      4
# 75239  218900        110          10   OPEN                     28
#
#        available_bikes  latitude  longitude    description    temp  humidity  \
# 0                   18     53.35      -6.26     few clouds  282.81        71
# 1                    2     53.35      -6.26     few clouds  282.81        71
# 2                   13     53.35      -6.26     few clouds  282.81        71
# 3                   13     53.35      -6.26     few clouds  282.81        71
# 4                    2     53.35      -6.26     few clouds  282.81        71
# ...                ...       ...        ...            ...     ...       ...
# 75235               17     53.35      -6.26  broken clouds  285.57        86
# 75236               11     53.35      -6.26  broken clouds  285.57        86
# 75237                3     53.35      -6.26  broken clouds  285.57        86
# 75238               24     53.35      -6.26  broken clouds  285.57        86
# 75239                2     53.35      -6.26  broken clouds  285.57        86
#
#        wind_speed weatherDate weatherMinute weatherSecond  cal_bike_stands
# 0           10.80  2022-02-22            00            00               30
# 1           10.80  2022-02-22            00            00               20
# 2           10.80  2022-02-22            00            00               33
# 3           10.80  2022-02-22            00            00               35
# 4           10.80  2022-02-22            00            00               40
# ...           ...         ...           ...           ...              ...
# 75235       10.84  2022-04-04            00            00               20
# 75236       10.84  2022-04-04            00            00               40
# 75237       10.84  2022-04-04            00            00               40
# 75238       10.84  2022-04-04            00            00               28
# 75239       10.84  2022-04-04            00            00               30
#
# [75240 rows x 16 columns]

# %%
# Change description to category type for numeric encoding
stationWeather['description'] = stationWeather['description'].astype('category')
stationWeather.dtypes
# Out:
# ID                          int64
# stationId                   int64
# weatherHour                object
# status                     object
# available_bike_stands       int64
# available_bikes             int64
# latitude                  float64
# longitude                 float64
# description              category
# temp                      float64
# humidity                    int64
# wind_speed                float64
# weatherDate                object
# weatherMinute              object
# weatherSecond              object
# cal_bike_stands             int64
# dtype: object

# %%
# Catergorical Encoding
stationWeather['num_desc'] = stationWeather['description'].cat.codes
stationWeather
# Out:
#            ID  stationId weatherHour status  available_bike_stands  \
# 0      143661          1          12   OPEN                     12
# 1      143662          2          12   OPEN                     18
# 2      143663          3          12   OPEN                     20
# 3      143664          4          12   OPEN                     22
# 4      143665          5          12   OPEN                     38
# ...       ...        ...         ...    ...                    ...
# 75235  218896        106          10   OPEN                      3
# 75236  218897        107          10   OPEN                     29
# 75237  218898        108          10   OPEN                     37
# 75238  218899        109          10   OPEN                      4
# 75239  218900        110          10   OPEN                     28
#
#        available_bikes  latitude  longitude    description    temp  humidity  \
# 0                   18     53.35      -6.26     few clouds  282.81        71
# 1                    2     53.35      -6.26     few clouds  282.81        71
# 2                   13     53.35      -6.26     few clouds  282.81        71
# 3                   13     53.35      -6.26     few clouds  282.81        71
# 4                    2     53.35      -6.26     few clouds  282.81        71
# ...                ...       ...        ...            ...     ...       ...
# 75235               17     53.35      -6.26  broken clouds  285.57        86
# 75236               11     53.35      -6.26  broken clouds  285.57        86
# 75237                3     53.35      -6.26  broken clouds  285.57        86
# 75238               24     53.35      -6.26  broken clouds  285.57        86
# 75239                2     53.35      -6.26  broken clouds  285.57        86
#
#        wind_speed weatherDate weatherMinute weatherSecond  cal_bike_stands  \
# 0           10.80  2022-02-22            00            00               30
# 1           10.80  2022-02-22            00            00               20
# 2           10.80  2022-02-22            00            00               33
# 3           10.80  2022-02-22            00            00               35
# 4           10.80  2022-02-22            00            00               40
# ...           ...         ...           ...           ...              ...
# 75235       10.84  2022-04-04            00            00               20
# 75236       10.84  2022-04-04            00            00               40
# 75237       10.84  2022-04-04            00            00               40
# 75238       10.84  2022-04-04            00            00               28
# 75239       10.84  2022-04-04            00            00               30
#
#        num_desc
# 0             2
# 1             2
# 2             2
# 3             2
# 4             2
# ...         ...
# 75235         0
# 75236         0
# 75237         0
# 75238         0
# 75239         0
#
# [75240 rows x 17 columns]

# %%
station1Weather = stationWeather.query('stationId == 1')
station1Weather
# Out:
#            ID  stationId weatherHour status  available_bike_stands  \
# 0      143661          1          12   OPEN                     12
# 110    143771          1          10   OPEN                     17
# 220    143881          1          09   OPEN                      8
# 330    143991          1          10   OPEN                     12
# 440    144101          1          11   OPEN                     14
# ...       ...        ...         ...    ...                    ...
# 74690  218351          1          06   OPEN                     17
# 74800  218461          1          07   OPEN                     22
# 74910  218571          1          08   OPEN                     24
# 75020  218681          1          09   OPEN                     26
# 75130  218791          1          10   OPEN                     28
#
#        available_bikes  latitude  longitude       description    temp  \
# 0                   18     53.35      -6.26        few clouds  282.81
# 110                 13     53.35      -6.26  scattered clouds  276.31
# 220                 22     53.35      -6.26         clear sky  277.21
# 330                 18     53.35      -6.26  scattered clouds  279.13
# 440                 16     53.35      -6.26     broken clouds  280.61
# ...                ...       ...        ...               ...     ...
# 74690               13     53.35      -6.26     broken clouds  283.60
# 74800                8     53.35      -6.26     broken clouds  283.86
# 74910                5     53.35      -6.26     broken clouds  284.18
# 75020                3     53.35      -6.26     broken clouds  284.66
# 75130                1     53.35      -6.26     broken clouds  285.57
#
#        humidity  wind_speed weatherDate weatherMinute weatherSecond  \
# 0            71       10.80  2022-02-22            00            00
# 110          80        9.77  2022-02-24            00            00
# 220          86        0.98  2022-03-01            00            00
# 330          83        1.78  2022-03-01            00            00
# 440          80        3.65  2022-03-01            00            00
# ...         ...         ...         ...           ...           ...
# 74690        91        9.39  2022-04-04            00            00
# 74800        90        8.45  2022-04-04            00            00
# 74910        89        9.12  2022-04-04            00            00
# 75020        89       10.12  2022-04-04            00            00
# 75130        86       10.84  2022-04-04            00            00
#
#        cal_bike_stands  num_desc
# 0                   30         2
# 110                 30        13
# 220                 30         1
# 330                 30        13
# 440                 30         0
# ...                ...       ...
# 74690               30         0
# 74800               30         0
# 74910               29         0
# 75020               29         0
# 75130               29         0
#
# [684 rows x 17 columns]

# %%
# Checking correlations for all the contious features
station1Weather.corr()
# Out:
#                              ID  stationId  available_bike_stands  \
# ID                     1.000000        NaN               0.171404
# stationId                   NaN        NaN                    NaN
# available_bike_stands  0.171404        NaN               1.000000
# available_bikes       -0.171881        NaN              -0.998649
# latitude                    NaN        NaN                    NaN
# longitude                   NaN        NaN                    NaN
# temp                   0.230413        NaN               0.415894
# humidity              -0.141198        NaN              -0.290735
# wind_speed            -0.238943        NaN               0.214522
# cal_bike_stands       -0.006992        NaN               0.038776
# num_desc               0.008602        NaN              -0.061299
#
#                        available_bikes  latitude  longitude      temp  \
# ID                           -0.171881       NaN        NaN  0.230413
# stationId                          NaN       NaN        NaN       NaN
# available_bike_stands        -0.998649       NaN        NaN  0.415894
# available_bikes               1.000000       NaN        NaN -0.414172
# latitude                           NaN       NaN        NaN       NaN
# longitude                          NaN       NaN        NaN       NaN
# temp                         -0.414172       NaN        NaN  1.000000
# humidity                      0.288218       NaN        NaN -0.467591
# wind_speed                   -0.215903       NaN        NaN  0.136850
# cal_bike_stands               0.013194       NaN        NaN  0.038439
# num_desc                      0.059812       NaN        NaN -0.033805
#
#                        humidity  wind_speed  cal_bike_stands  num_desc
# ID                    -0.141198   -0.238943        -0.006992  0.008602
# stationId                   NaN         NaN              NaN       NaN
# available_bike_stands -0.290735    0.214522         0.038776 -0.061299
# available_bikes        0.288218   -0.215903         0.013194  0.059812
# latitude                    NaN         NaN              NaN       NaN
# longitude                   NaN         NaN              NaN       NaN
# temp                  -0.467591    0.136850         0.038439 -0.033805
# humidity               1.000000   -0.178957        -0.052140 -0.049107
# wind_speed            -0.178957    1.000000        -0.023807  0.011951
# cal_bike_stands       -0.052140   -0.023807         1.000000 -0.029395
# num_desc              -0.049107    0.011951        -0.029395  1.000000

# %% [markdown]
# # Multiple Linear Regression

# %%
X = station1Weather[['stationId', 'weatherHour', 'temp', 'humidity', 'wind_speed', 'cal_bike_stands', 'num_desc']]
y = station1Weather.available_bikes

# %% [markdown]
# <h2>Training</h2>

# %%
linreg = LinearRegression().fit(X, y)

# Weights for each Feature
print("Features: \n", X)
print("Coeficients: \n", linreg.coef_)
print("\nIntercept: \n", linreg.intercept_)

feature_importance = pd.DataFrame({'feature': ['stationId', 'weatherHour', 'temp', 'humidity', 'wind_speed', 'cal_bike_stands', 'num_desc'], 'importance':linreg.coef_})
feature_importance.sort_values('importance', ascending=False)
# Out:
# Features:
#         stationId weatherHour    temp  humidity  wind_speed  cal_bike_stands  \
# 0              1          12  282.81        71       10.80               30
# 110            1          10  276.31        80        9.77               30
# 220            1          09  277.21        86        0.98               30
# 330            1          10  279.13        83        1.78               30
# 440            1          11  280.61        80        3.65               30
# ...          ...         ...     ...       ...         ...              ...
# 74690          1          06  283.60        91        9.39               30
# 74800          1          07  283.86        90        8.45               30
# 74910          1          08  284.18        89        9.12               29
# 75020          1          09  284.66        89       10.12               29
# 75130          1          10  285.57        86       10.84               29
#
#        num_desc
# 0             2
# 110          13
# 220           1
# 330          13
# 440           0
# ...         ...
# 74690         0
# 74800         0
# 74910         0
# 75020         0
# 75130         0
#
# [684 rows x 7 columns]
# Coeficients:
#  [ 0.          0.0791899  -0.85409528  0.08377113 -0.46090536  0.4384758
#   0.09070202]
#
# Intercept:
#  241.65324407757961
#            feature  importance
# 5  cal_bike_stands    0.438476
# 6         num_desc    0.090702
# 3         humidity    0.083771
# 1      weatherHour    0.079190
# 0        stationId    0.000000
# 4       wind_speed   -0.460905
# 2             temp   -0.854095

# %%
# Serialize model object into a file called model.pkl on disk using pickle
with open('dwmb_resample_singleStation_linReg_model.pkl', 'wb') as handle:
    pickle.dump(linreg, handle, pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# <h2>Testing</h2>

# %%
linreg_predictions = linreg.predict(X)
print(type(linreg_predictions))

print("\nPredictions with linear regression: \n")
actual_vs_predicted_linreg = pd.concat([y, pd.DataFrame(linreg_predictions, columns=['Predicted'], index=y.index)], axis=1)
print(actual_vs_predicted_linreg)
# Out:
# <class 'numpy.ndarray'>
#
# Predictions with linear regression:
#
#        available_bikes  Predicted
# 0                   18  15.362488
# 110                 13  22.982123
# 220                 22  25.599808
# 330                 18  24.507521
# 440                 16  21.030317
# ...                ...        ...
# 74690               13  16.356509
# 74800                8  16.563114
# 74910                5  15.537940
# 75020                3  14.746258
# 75130                1  13.465056
#
# [684 rows x 2 columns]

# %%
print(X.columns)
small_linreg = [X.iloc[0]]
Small_linreg_predictions = linreg.predict(small_linreg)
print(type(linreg_predictions))
# Out:
# Index(['stationId', 'weatherHour', 'temp', 'humidity', 'wind_speed',
#        'cal_bike_stands', 'num_desc'],
#       dtype='object')
# <class 'numpy.ndarray'>
# C:\Users\Rachel\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: FutureWarning: Arrays of bytes/strings is being converted to decimal numbers if dtype='numeric'. This behavior is deprecated in 0.24 and will be removed in 1.1 (renaming of 0.26). Please convert your data to numeric values explicitly instead.
#   return f(*args, **kwargs)

# %%
# Prototyping the results for /predict
# convert numpy array to dictionary
temp_results = dict(enumerate(Small_linreg_predictions.flatten(), 1))

# print numpy array
print(Small_linreg_predictions)
print(type(Small_linreg_predictions))
 
# print dictionary
print(temp_results)
print(type(temp_results))
# Out:
# [15.36248817]
# <class 'numpy.ndarray'>
# {1: 15.362488169148492}
# <class 'dict'>

# %%
prediction_errors = y - linreg_predictions
print("Actual - Predicted:\n", prediction_errors)
print("\n(Actual - Predicted) squared:\n", prediction_errors**2)
print("\n Sum of (Actual - Predicted) squared:\n", (prediction_errors**2).sum())
# Out:
# Actual - Predicted:
#  0         2.637512
# 110      -9.982123
# 220      -3.599808
# 330      -6.507521
# 440      -5.030317
#            ...
# 74690    -3.356509
# 74800    -8.563114
# 74910   -10.537940
# 75020   -11.746258
# 75130   -12.465056
# Name: available_bikes, Length: 684, dtype: float64
#
# (Actual - Predicted) squared:
#  0          6.956469
# 110       99.642772
# 220       12.958615
# 330       42.347832
# 440       25.304093
#             ...
# 74690     11.266151
# 74800     73.326917
# 74910    111.048171
# 75020    137.974587
# 75130    155.377630
# Name: available_bikes, Length: 684, dtype: float64
#
#  Sum of (Actual - Predicted) squared:
#  33993.644956226126

# %%
# Mean Squared Error
mse = (prediction_errors** 2).mean()
rmse = ((prediction_errors** 2).mean())**0.5

print("\nMean Squared Error:\n", mse)
print("\nRoot Mean Squared Error:\n", rmse)
# Out:
# Mean Squared Error:
#  49.6983113395119
#
# Root Mean Squared Error:
#  7.049702925621186

# %%
print("|Actual - Predicted|:\n", abs(prediction_errors))
# Out:
# |Actual - Predicted|:
#  0         2.637512
# 110       9.982123
# 220       3.599808
# 330       6.507521
# 440       5.030317
#            ...
# 74690     3.356509
# 74800     8.563114
# 74910    10.537940
# 75020    11.746258
# 75130    12.465056
# Name: available_bikes, Length: 684, dtype: float64

# %%
# Mean Absolute Error
mae = abs(prediction_errors).mean()
print("\nMean Absolute Error:\n", mae)
# Out:
# Mean Absolute Error:
#  5.839607618943632

# %%
# R2 Score
prediction_errors = y - linreg_predictions
print("Actual - Predicted:\n", prediction_errors)
print("\n(Actual - Predicted) squared:\n", prediction_errors**2)
print("\n Sum of squared errors:\n", sum(prediction_errors**2))

avg_predictions =np.ones(y.shape[0])* station1Weather.available_bikes.mean()

print("\nAverageModelPredictions:\n", avg_predictions)
avgpredictions_errors = y - avg_predictions
print("Actual - AvgPredictions:\n", avgpredictions_errors)
print("\n(Actual - AvgPredictions) squared:\n", avgpredictions_errors**2)
print("\n Total sum of squared errors:\n", sum(avgpredictions_errors**2))

r2 = 1 - sum(prediction_errors**2)/sum(avgpredictions_errors**2)
print("\n R2:\n", r2)
# Out:
# Actual - Predicted:
#  0         2.637512
# 110      -9.982123
# 220      -3.599808
# 330      -6.507521
# 440      -5.030317
#            ...
# 74690    -3.356509
# 74800    -8.563114
# 74910   -10.537940
# 75020   -11.746258
# 75130   -12.465056
# Name: available_bikes, Length: 684, dtype: float64
#
# (Actual - Predicted) squared:
#  0          6.956469
# 110       99.642772
# 220       12.958615
# 330       42.347832
# 440       25.304093
#             ...
# 74690     11.266151
# 74800     73.326917
# 74910    111.048171
# 75020    137.974587
# 75130    155.377630
# Name: available_bikes, Length: 684, dtype: float64
#
#  Sum of squared errors:
#  33993.64495622614
#
# AverageModelPredictions:
#  [19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485
#  19.89327485 19.89327485 19.89327485 19.89327485 19.89327485 19.89327485]
# Actual - AvgPredictions:
#  0        -1.893275
# 110      -6.893275
# 220       2.106725
# 330      -1.893275
# 440      -3.893275
#            ...
# 74690    -6.893275
# 74800   -11.893275
# 74910   -14.893275
# 75020   -16.893275
# 75130   -18.893275
# Name: available_bikes, Length: 684, dtype: float64
#
# (Actual - AvgPredictions) squared:
#  0          3.584490
# 110       47.517238
# 220        4.438291
# 330        3.584490
# 440       15.157589
#             ...
# 74690     47.517238
# 74800    141.449987
# 74910    221.809636
# 75020    285.382735
# 75130    356.955835
# Name: available_bikes, Length: 684, dtype: float64
#
#  Total sum of squared errors:
#  43157.2090643275
#
#  R2:
#  0.21232985882944166

# %%
# Function to output evaluation metrics
def printMetrics(testActualVal, predictions):
    #classification evaluation measures
    print('\n==============================================================================')
    print("MAE: ", metrics.mean_absolute_error(testActualVal, predictions))
    #print("MSE: ", metrics.mean_squared_error(testActualVal, predictions))
    print("RMSE: ", metrics.mean_squared_error(testActualVal, predictions)**0.5)
    print("R2: ", metrics.r2_score(testActualVal, predictions))

# %%
printMetrics(y, linreg_predictions)
# Out:
# ==============================================================================
# MAE:  5.839607618943638
# RMSE:  7.049702925621184
# R2:  0.21232985882944178
